# %%
import pandas as pd

inout_data = pd.DataFrame({
    'code': ['ABC123', 'DEF456', 'GHI789', 'D1F456', 'DEF2456'],
    'name': ['Sản phẩm 1', 'Sản phẩm 2', 'Sản phẩm 3', 'Sản phẩm 4', 'Sản phẩm 5'],
    'quantity': [10, 20, 30,35,12],
    'price':[10000, 20000, 30000,66000,440000] ,
    'type_code': [1,2,3,2,6]

    })

inout_data.to_csv('products.csv')
          
sell_data = pd.DataFrame({
    'code': ['ABC123', 'DEF456', 'GHI789'],   
    'quantity_sell':[10, 20, 30] ,
    'day': [1,2,3], 
      
    })

sell_data.to_csv('sell_data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 59
#      56         self.df_rows = self.df.to_numpy().tolist()
#      57         self.display_all_data()
# ---> 59 app = App()
#      60 app.mainloop()
#
# Cell In[7], line 12, in App.__init__(self)
#      10 # Create Dropdown Menus
#      11 self.search_options = ttk.Combobox(self, width=20)
# ---> 12 self.search_options["values"] =  list( self.df['product_type'].unique())
#      13 self.search_options.pack(pady=10)
#      16  # Create Search button
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'product_type'

# %%
import tkinter as tk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Tạo cửa sổ chính
window = tk.Tk()
window.title("Thống kê báo cáo sản phẩm")

# Tạo hộp văn bản để nhập dữ liệu
entry_data = tk.Entry(window, width=100)
entry_data.pack()

# Tạo nút để bắt đầu phân tích
button_start = tk.Button(window, text="Bắt đầu", command=lambda: start_analysis())
button_start.pack()

# Tạo hộp văn bản để hiển thị kết quả
text_result = tk.Text(window, width=100, height=20)
text_result.pack()

# Hàm bắt đầu phân tích
def start_analysis():
    # Nhận dữ liệu từ hộp văn bản
    data = pd.read_csv("products.csv").to_numpy()
    print(data)

    # Chuyển đổi dữ liệu thành mảng NumPy
   
    # Thống kê dữ liệu
    mean = np.mean(data)
    std = np.std(data)

    # Tạo biểu đồ phân bố dữ liệu
    plt.hist(data)
    plt.axvline(mean, color="red")
    plt.axvline(mean + std, color="green")
    plt.axvline(mean - std, color="green")
    plt.show()

    # Hiển thị kết quả
    text_result.delete(1.0, "end")
    text_result.insert(1.0, "Kết quả thống kê: \n\n"
                         "Trung bình: {:.2f}\n"
                         "Độ lệch chuẩn: {:.2f}".format(mean, std))

# Chạy chương trình
window.mainloop()
# Out:
# [[0 'ABC123' 'Sản phẩm 1' 10 10000.0 1]
#  [1 'DEF456' 'Sản phẩm 2' 20 20000.0 2]
#  [2 'GHI789' 'Sản phẩm 3' 30 30000.0 3]
#  [3 'D1F456' 'Sản phẩm 4' 35 66000.0 2]
#  [4 'DEF2456' 'Sản phẩm 5' 12 440000.0 6]
#  [6 'AH11' 'Tivi ABC' 12 300000.0 1]
#  [7 'AH12' 'Tivi ASD' 4 390000.0 1]
#  [8 'LT1224' 'Latop cn' 10 990000.0 2]
#  [9 'MB1224' 'IIphone 1' 10 610000.0 3]
#  [10 'MB124' 'GG Phone' 15 210000.0 3]
#  [11 'CM1024' 'Sony SSS' 15 510000.0 7]
#  [12 'CM1024' 'CN Sh' 3 410000.0 7]
#  [13 'SS1024' 'SS sony 1' 7 300000.0 5]
#  [14 'SP234' 'Quạt điện 1s' 25 150000.0 16]
#  [15 'SP235' 'Quạt điện 2s' 20 170000.0 16]
#  [16 'MB1233' 'Nokia 1080' 30 170000.0 3]]
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hieua\AppData\Local\Programs\Python\Python39\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\hieua\AppData\Local\Temp\ipykernel_16160\3465223172.py", line 15, in <lambda>
#     button_start = tk.Button(window, text="Bắt đầu", command=lambda: start_analysis())
#   File "C:\Users\hieua\AppData\Local\Temp\ipykernel_16160\3465223172.py", line 31, in start_analysis
#     mean = np.mean(data)
#   File "C:\Users\hieua\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py", line 3504, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "C:\Users\hieua\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py", line 118, in _mean
#     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
import pandas as pd

# Danh sách các thiết bị điện tử theo chức năng
devices_by_function = [
    # Thiết bị điện tử gia dụng
    ["Tivi", "Television"],
    ["Máy tính", "Computer"],
    ["Điện thoại", "Phone"],
    ["Máy tính bảng", "Tablet"],
    ["Loa", "Speaker"],
    ["Tai nghe", "Headphone"],
    ["Máy ảnh", "Camera"],
    ["Máy quay phim", "Video camera"],
    ["Máy chơi game", "Game console"],
    # Thiết bị điện tử gia dụng khác
    ["Lò vi sóng", "Microwave"],
    ["Máy giặt", "Washing machine"],
    ["Máy sấy quần áo", "Dryer"],
    ["Máy rửa bát", "Dishwasher"],
    ["Máy hút bụi", "Vacuum cleaner"],
    ["Nồi cơm điện", "Rice cooker"],
    ["Quạt điện", "Fan"],
    ["Ấm đun nước", "Kettle"],
    ["Bàn ủi", "Iron"],
    

]

# Tạo DataFrame
df = pd.DataFrame(devices_by_function, columns=["type_name", "type_code"])

# Thêm cột "Mã danh mục"
df["type_code"] = pd.Series(range(1, len(df) + 1))

df.to_csv('category.csv')

# %%
import pandas as pd


    
def add_category(cates,newcate):
    cates.append({
        'name': newcate
         })
def save_category(cates):
    data.to_csv('categotys.csv')
def save_data(data,fl='products.csv'):
    data.to_csv(fl)
def delete_data(product_data,data):
    product_data = product_data.drop(data)
def read_data(fl='products.csv'):
    data = pd.read_csv(fl)
    return data

def show_data(data):
    print(data.to_string())


def delete_row(data,index):
    return data.pop(index)
def add_pr(code,name,quantity,price,product_type):
        # Thêm dữ liệu
    data=read_data()
    data.loc[len(data.index)] = [str(name),int(quantity), str(code),float(price),str(product_type)] 

    print(data)
    save_data(data)

# %%
cate=read_data("category.csv")
pro=read_data("products.csv")
sell=read_data("sell_data.csv")






ss_df = pd.merge(left=pro, right=sell, on='code')

# In DataFrame
print(ss_df)

ttsk=ss_df.groupby(['code','name'])['quantity_sell'].sum().sort_values(ascending=True)
print(ttsk)
# Out:
#    Unnamed: 0_x    code        name  quantity     price  type_code  \
# 0             0  ABC123  Sản phẩm 1        10   10000.0          1
# 1             0  ABC123  Sản phẩm 1        10   10000.0          1
# 2             0  ABC123  Sản phẩm 1        10   10000.0          1
# 3             1  DEF456  Sản phẩm 2        20   20000.0          2
# 4             2  GHI789  Sản phẩm 3        30   30000.0          3
# 5             2  GHI789  Sản phẩm 3        30   30000.0          3
# 6             8  LT1224    Latop cn        10  990000.0          2
# 7             8  LT1224    Latop cn        10  990000.0          2
#
#    Unnamed: 0_y  quantity_sell       day
# 0             0             10         1
# 1             4              1  1/1/2023
# 2             5              2  1/1/2023
# 3             1             20         2
# 4             2             30         3
# 5             6              2  1/1/2023
# 6             7              2  1/1/2023
# 7             8              4  1/1/2023
# code    name
# LT1224  Latop cn       6
# ABC123  Sản phẩm 1    13
# DEF456  Sản phẩm 2    20
# GHI789  Sản phẩm 3    32
# Name: quantity_sell, dtype: int64

# %%
data = pd.merge(left=pro, right=sell, on='code')

data=data.groupby(['code','name','price'])[['quantity_sell']].sum()

colors = plt.cm.Set1.colors[:len(data)]


# Tần số đơn hàng theo Gender


# Vẽ biểu đồ cột
plt.figure(figsize=(9, 4))
plt.bar(data.index.get_level_values("name"), data['quantity_sell'],color=colors)
plt.xlabel("Sản phẩm")
plt.ylabel("Số lượng đơn hàng")
plt.title("Số đơn hàng theo sản phẩm")
plt.show()


data['sales_total']= data['quantity_sell']*data.index.get_level_values("price")

plt.figure(figsize=(9, 4))
plt.bar(data.index.get_level_values("name"), data['sales_total'], color=colors)



plt.title("Giá trị sản phẩm đa bán theo sẻn phẩm")
plt.xlabel("sản phẩm")
plt.ylabel("tổng tiền")

# Hiển thị biểu đồ

plt.show()

# %%
import tkinter as tk
from tkinter import ttk
root = tk.Tk()

treeview = ttk.Treeview(root)
treeview.pack()

# Kích hoạt tính năng tự động thay đổi kích thước
treeview.pack_propagate(False)

# Thiết lập kích thước cửa sổ


# Thêm các hàng và cột vào Treeview
for i in range(10):
    treeview.insert("", "end", text=str(i)+"4555555555555555555555555555555")

root.mainloop()

# %%
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk

# Tạo dữ liệu
x = np.arange(0, 10)
y = x ** 2

# Tạo các hàm vẽ đồ thị
def plot_line(x, y):
    plt.plot(x, y)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()

def plot_bar(x, y):
    plt.bar(x, y)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()

def plot_pie(x, y):
    plt.pie(y, labels=x)
    plt.show()

# Tạo giao diện người dùng
root = tk.Tk()

# Tạo các nút
line_button = tk.Button(root, text="Biểu đồ đường", command=lambda: plot_line(x, y))
bar_button = tk.Button(root, text="Biểu đồ cột", command=lambda: plot_bar(x, y))
pie_button = tk.Button(root, text="Biểu đồ tròn", command=lambda: plot_pie(x, y))

# Sắp xếp các nút
line_button.pack()
bar_button.pack()
pie_button.pack()

# Khởi động vòng lặp chính
root.mainloop()

# %%
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk

# Tạo dữ liệu
x = np.arange(0, 10)
y = x ** 2

# Tạo giao diện người dùng
root = tk.Tk()

# Tạo canvas
canvas = tk.Canvas(root, width=500, height=500)

# Vẽ biểu đồ đường
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# Thêm canvas vào giao diện người dùng
canvas.pack()

# Cập nhật biểu đồ đường mỗi giây
def update_graph():
    global x, y

    x = x + 1
    y = x ** 2

    # Vẽ biểu đồ đường mới
    plt.cla()
    plt.plot(x, y)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()

    # Đặt lại thời gian chờ
    canvas.after(1000, update_graph)

# Khởi động vòng lặp chính
update_graph()
root.mainloop()

# %%
import tkinter as tk

# Tạo cửa sổ
root = tk.Tk()

# Tạo nhãn cho ô mã sản phẩm
label_ma_san_pham = tk.Label(root, text="Mã sản phẩm")

# Tạo ô nhập mã sản phẩm
entry_ma_san_pham = tk.Entry(root)

# Tạo nhãn cho ô tên sản phẩm
label_ten_san_pham = tk.Label(root, text="Tên sản phẩm")

# Tạo ô nhập tên sản phẩm
entry_ten_san_pham = tk.Entry(root)

# Tạo nhãn cho ô số lượng
label_so_luong = tk.Label(root, text="Số lượng")

# Tạo ô nhập số lượng
entry_so_luong = tk.Entry(root)

# Tạo nhãn cho ô ngày bán
label_ngay_ban = tk.Label(root, text="Ngày bán")

# Tạo ô chọn ngày bán
entry_ngay_ban = tk.Entry(root, width=10)

# Tạo nút "Thêm"
button_them = tk.Button(root, text="Thêm")

# Sắp xếp các widget
label_ma_san_pham.grid(row=0, column=0)
entry_ma_san_pham.grid(row=0, column=1)
label_ten_san_pham.grid(row=1, column=0)
entry_ten_san_pham.grid(row=1, column=1)
label_so_luong.grid(row=2, column=0)
entry_so_luong.grid(row=2, column=1)
label_ngay_ban.grid(row=3, column=0)
entry_ngay_ban.grid(row=3, column=1)
button_them.grid(row=4, column=1)

# Bắt sự kiện khi nhấn nút "Thêm"
def on_click_them():
    # Lấy dữ liệu từ các ô nhập
    ma_san_pham = entry_ma_san_pham.get()
    ten_san_pham = entry_ten_san_pham.get()
    so_luong = entry_so_luong.get()
    ngay_ban = entry_ngay_ban.get()

    # In thông tin đã nhập
    print(f"Mã sản phẩm: {ma_san_pham}")
    print(f"Tên sản phẩm: {ten_san_pham}")
    print(f"Số lượng: {so_luong}")
    print(f"Ngày bán: {ngay_ban}")

button_them.config(command=on_click_them)

# Chạy cửa sổ
root.mainloop()
# Out:
# Mã sản phẩm:
# Tên sản phẩm:
# Số lượng:
# Ngày bán: tỷteytrytryr
